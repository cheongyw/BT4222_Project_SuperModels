# %%
# restart kernel after running this cell
# !pip install pandas --upgrade
# Out:
# ...
#     100% |████████████████████████████████| 10.1MB 3.4MB/s
# ...
# fastai 1.0.51 has requirement numpy>=1.15, but you'll have numpy 1.14.6 which is incompatible.
# ...
#   Found existing installation: pandas 0.22.0
#     Uninstalling pandas-0.22.0:
#       Successfully uninstalled pandas-0.22.0
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from bs4 import BeautifulSoup
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
from datetime import datetime
import os
import glob
import re
import math
import json
import random

from IPython import display
from matplotlib import cm

import tensorflow as tf
from tensorflow.python.data import Dataset

from google.colab import drive
drive.mount('/content/drive')

import lightgbm as lgb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from itertools import chain
import time
import multiprocessing
import copy
import pickle
import datetime as dt
import h5py
import re
from subprocess import call
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.manifold import TSNE
from sklearn.neighbors import NearestNeighbors
import keras
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from keras.models import load_model
from keras import Model
from keras import backend as K
from keras.utils import to_categorical
import gc
from keras.layers import Input, LSTM, Bidirectional, Dense, Embedding, Flatten
from gensim.models import Word2Vec
# %matplotlib inline

import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# Using TensorFlow backend.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
os.listdir('/content/drive/My Drive/BT4222 Group/workspace/output/')
# Out:
# ['growing_final_output_from_results_dict_V1.p',
#  'sliding_final_output_from_results_dict.p',
#  'growing_partial_final_output_from_results_dict_V7.p',
#  'sliding_final_output_from_results_dict_V6.p',
#  'sliding_final_output_from_results_dict_V5.p',
#  'sliding_final_output_from_results_dict_V4.p',
#  'word2vec diagram.jpg',
#  'sliding_final_output_from_results_dict_V7.p',
#  'sliding_final_output_from_results_dict_V1_and_V2.p',
#  'growing_final_output_from_results_dict_V3.p']

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  for year in result_pickle[v_str]:
    avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v1
# year: 2011, sigma: 0.265544
# year: 2012, sigma: 0.809726
# year: 2013, sigma: 0.614858
# year: 2014, sigma: 0.147481
# year: 2015, sigma: 0.400858
# average sigma: 0.447693
#
# Version String: v2
# year: 2011, sigma: 0.243268
# year: 2012, sigma: 0.809460
# year: 2013, sigma: 0.617171
# year: 2014, sigma: 0.156190
# year: 2015, sigma: 0.413598
# average sigma: 0.447937
#
# Version String: v4
# year: 2011, sigma: 0.253534
# year: 2012, sigma: 0.854475
# year: 2013, sigma: 0.645191
# year: 2014, sigma: -0.006878
# year: 2015, sigma: 0.496047
# average sigma: 0.448474
#
# Version String: v5
# year: 2011, sigma: 0.216132
# year: 2012, sigma: 0.782206
# year: 2013, sigma: 0.658939
# year: 2014, sigma: 0.209596
# year: 2015, sigma: 0.499271
# average sigma: 0.473229
#
# Version String: v6
# year: 2011, sigma: 0.224684
# year: 2012, sigma: 0.749134
# year: 2013, sigma: 0.663432
# year: 2014, sigma: 0.364654
# year: 2015, sigma: 0.207281
# average sigma: 0.441837

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V1_and_V2.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v1
# year: 2011, sigma: 0.240066
# year: 2012, sigma: 0.793952
# year: 2013, sigma: 0.609352
# year: 2014, sigma: 0.163212
# year: 2015, sigma: 0.385548
# year: 2016, sigma: 0.433380
# average sigma: 0.438426
#
# Version String: v2
# year: 2011, sigma: 0.238026
# year: 2012, sigma: 0.764929
# year: 2013, sigma: 0.625804
# year: 2014, sigma: 0.026845
# year: 2015, sigma: 0.385804
# year: 2016, sigma: 0.450828
# average sigma: 0.408281

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/growing_final_output_from_results_dict_V3.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v3
# year: 2011, sigma: 0.234246
# year: 2012, sigma: 0.830408
# year: 2013, sigma: 0.409676
# year: 2014, sigma: -0.023169
# year: 2015, sigma: 0.409455
# average sigma: 0.372123

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V4.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v4
# year: 2011, sigma: 0.251577
# year: 2012, sigma: 0.861726
# year: 2013, sigma: 0.642337
# year: 2014, sigma: -0.018428
# year: 2015, sigma: 0.377148
# year: 2016, sigma: 0.485014
# average sigma: 0.422872

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V5.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v5
# year: 2011, sigma: 0.208302
# year: 2012, sigma: 0.784137
# year: 2013, sigma: 0.662090
# year: 2014, sigma: 0.211456
# year: 2015, sigma: 0.314295
# year: 2016, sigma: 0.533894
# average sigma: 0.436056

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V6.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v6
# year: 2011, sigma: 0.303233
# year: 2012, sigma: 0.774108
# year: 2013, sigma: 0.671013
# year: 2014, sigma: 0.332549
# year: 2015, sigma: 0.348603
# year: 2016, sigma: 0.407380
# average sigma: 0.485901

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V6.p', 'rb'))

v_str = 'v6'

conf_mat = np.array([[0,0], [0,0]])

count = 0
for year in result_pickle[v_str]: #[year]['sigma_score']:
  count += 1
  if count == 6:
    break
  conf_mat += result_pickle[v_str][year]['conf_mat']
  

print('accuracy: %f' % ((conf_mat[0, 0] + conf_mat[1, 1]) / conf_mat.sum()))
# Out:
# accuracy: 0.538332

# %%
conf_mat
# Out:
# array([[228003, 192587],
#        [195408, 224422]])

# %%
conf_mat
# Out:
# array([[56806, 29135],
#        [54390, 40101]])

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V6.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')

# %%
result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/sliding_final_output_from_results_dict_V7.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count  <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# Version String: v7
# year: 2011, sigma: 0.216180
# year: 2012, sigma: 0.743098
# year: 2013, sigma: 0.661086
# year: 2014, sigma: 0.351743
# year: 2015, sigma: 0.183718
# year: 2016, sigma: 0.519554
# average sigma: 0.431165

# %%
print('growing v1')
print('')

result_pickle = pickle.load(open('/content/drive/My Drive/BT4222 Group/workspace/output/growing_final_output_from_results_dict_V1.p', 'rb'))

for v_str in result_pickle:
  print('Version String: %s' % v_str)
  avg_score = 0
  count = 0
  for year in result_pickle[v_str]:
    count += 1
    if count <= 5:
      avg_score += result_pickle[v_str][year]['sigma_score']
    print('year: %d, sigma: %f' % (year, result_pickle[v_str][year]['sigma_score']))
  print('average sigma: %f' % (avg_score / float(5)))
  print('')
# Out:
# growing v1
#
# Version String: v1
# year: 2011, sigma: 0.228986
# year: 2012, sigma: 0.746152
# year: 2013, sigma: 0.399148
# year: 2014, sigma: 0.030763
# year: 2015, sigma: 0.513805
# year: 2016, sigma: 0.386042
# average sigma: 0.383771

# %%
# Version String: v1
# year: 2011, sigma: 0.240066
# year: 2012, sigma: 0.793952
# year: 2013, sigma: 0.609352
# year: 2014, sigma: 0.163212
# year: 2015, sigma: 0.385548
# year: 2016, sigma: 0.433380
# average sigma: 0.438426
